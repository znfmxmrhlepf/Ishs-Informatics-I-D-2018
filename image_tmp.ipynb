# %%
img = imread('/home/haneul/Downloads/Telegram Desktop/photo_2018-08-01_15-45-38.jpg')
plt.imshow(img)
plt.show()

# %%
img
# Out:
# array([[[209, 167, 119],
#         [208, 166, 118],
#         [207, 165, 117],
#         ...,
#         [194, 160, 123],
#         [191, 158, 123],
#         [188, 158, 124]],
#
#        [[209, 167, 119],
#         [208, 166, 118],
#         [207, 165, 117],
#         ...,
#         [193, 159, 122],
#         [192, 159, 124],
#         [190, 160, 126]],
#
#        [[207, 167, 118],
#         [207, 167, 118],
#         [206, 166, 117],
#         ...,
#         [192, 158, 121],
#         [193, 160, 125],
#         [192, 162, 128]],
#
#        ...,
#
#        [[176, 150, 133],
#         [176, 150, 133],
#         [176, 150, 133],
#         ...,
#         [172, 146, 129],
#         [172, 146, 129],
#         [173, 147, 130]],
#
#        [[175, 149, 132],
#         [176, 150, 133],
#         [176, 150, 133],
#         ...,
#         [172, 146, 129],
#         [172, 146, 129],
#         [173, 147, 130]],
#
#        [[175, 149, 132],
#         [176, 150, 133],
#         [176, 150, 133],
# ...

# %%
img.size
# Out:
# 3686400

# %%
img[].size
# Out:
#   File "<ipython-input-21-9d8be258103b>", line 1
#     img[].size
#         ^
# SyntaxError: invalid syntax

# %%
img[0].size
# Out:
# 2880

# %%
3686400/2880
# Out:
# 1280.0

# %%
img.setflags(write=1)

# %%
for i in range(img.size//img[0].size):
    for j in range(img[0].size//img[0][0].size):
        for k in range(3):
            img[i][j][k]=2**8-1-img[i][j][k]
            
plt.imshow(img)
plt.show()
